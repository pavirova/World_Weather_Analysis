# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=015bdc0d028070b1137dbe91bf3713a3

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | okhotsk
# Processing Record 3 of Set 1 | ilhabela
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | vestmannaeyjar
# Processing Record 7 of Set 1 | aklavik
# Processing Record 8 of Set 1 | ostrovnoy
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | zaozerne
# Processing Record 11 of Set 1 | mocuba
# Processing Record 12 of Set 1 | mangrol
# Processing Record 13 of Set 1 | henzada
# City not found. Skipping...
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | bathsheba
# Processing Record 17 of Set 1 | american canyon
# Processing Record 18 of Set 1 | omboue
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | nome
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | kilgore
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | lasa
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | wexford
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | henties bay
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 1 | sorland
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | balkanabat
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | fairbanks
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | mazagao
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | chernyshevskiy
# Processing Record 44 of Set 1 | victoria
# Processing Record 45 of Set 1 | arman
# Processing Record 46 of Set 1 | concepcion del oro
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | urengoy
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | hachinohe
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | tautira
# Processing Record 9 of Set 2 | ilulissat
# Processing Record 10 of Set 2 | cidreira
# Processing Record 11 of Set 2 | vazante
# Processing Record 12 of Set 2 | koulikoro
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | praia da vitoria
# Processing Record 15 of Set 2 | west plains
# Processing Record 16 of Set 2 | ayan
# Processing Record 17 of Set 2 | torbat-e jam
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | yeniseysk
# Processing Record 21 of Set 2 | corrales
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | broome
# Processing Record 24 of Set 2 | chuy
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | diamantino
# Processing Record 27 of Set 2 | miyako
# Processing Record 28 of Set 2 | honningsvag
# Processing Record 29 of Set 2 | chapais
# Processing Record 30 of Set 2 | chingirlau
# Processing Record 31 of Set 2 | batsfjord
# Processing Record 32 of Set 2 | kavieng
# Processing Record 33 of Set 2 | pacific grove
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | tete
# Processing Record 36 of Set 2 | intipuca
# Processing Record 37 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | nioro
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | kidal
# Processing Record 43 of Set 2 | martaban
# Processing Record 44 of Set 2 | guiratinga
# Processing Record 45 of Set 2 | beringovskiy
# Processing Record 46 of Set 2 | zyryanka
# Processing Record 47 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 2 | linfen
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | port macquarie
# Processing Record 2 of Set 3 | ushuaia
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 3 | coahuayana
# Processing Record 6 of Set 3 | zeya
# Processing Record 7 of Set 3 | olafsvik
# Processing Record 8 of Set 3 | touros
# Processing Record 9 of Set 3 | maryville
# Processing Record 10 of Set 3 | burica
# City not found. Skipping...
# Processing Record 11 of Set 3 | superior
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | saint george
# Processing Record 14 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 3 | richards bay
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | berlevag
# Processing Record 18 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 3 | ponta do sol
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | merauke
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | sarai alamgir
# Processing Record 24 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 3 | menongue
# Processing Record 28 of Set 3 | port blair
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | ilo
# Processing Record 31 of Set 3 | necochea
# Processing Record 32 of Set 3 | katsuura
# Processing Record 33 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 3 | sao joao da barra
# Processing Record 35 of Set 3 | vila franca do campo
# Processing Record 36 of Set 3 | takhatgarh
# Processing Record 37 of Set 3 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 38 of Set 3 | verdalsora
# City not found. Skipping...
# Processing Record 39 of Set 3 | shestakovo
# Processing Record 40 of Set 3 | bud
# Processing Record 41 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 3 | saint-francois
# Processing Record 43 of Set 3 | marshfield
# Processing Record 44 of Set 3 | prestea
# Processing Record 45 of Set 3 | salvador
# Processing Record 46 of Set 3 | kahului
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | husavik
# Processing Record 49 of Set 3 | bowen
# Processing Record 50 of Set 3 | dalinghe
# City not found. Skipping...
# Processing Record 1 of Set 4 | homer
# Processing Record 2 of Set 4 | krasnaya poyma
# Processing Record 3 of Set 4 | antalaha
# Processing Record 4 of Set 4 | cap malheureux
# Processing Record 5 of Set 4 | bagdarin
# Processing Record 6 of Set 4 | manzanillo
# Processing Record 7 of Set 4 | klang
# Processing Record 8 of Set 4 | buala
# Processing Record 9 of Set 4 | hofn
# Processing Record 10 of Set 4 | leo
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | northam
# Processing Record 13 of Set 4 | jalu
# Processing Record 14 of Set 4 | fort nelson
# Processing Record 15 of Set 4 | bengkulu
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 4 | wanning
# Processing Record 19 of Set 4 | yellowknife
# Processing Record 20 of Set 4 | shahr-e kord
# Processing Record 21 of Set 4 | maniitsoq
# Processing Record 22 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 4 | calama
# Processing Record 24 of Set 4 | constitucion
# Processing Record 25 of Set 4 | kaminoyama
# Processing Record 26 of Set 4 | aleksandrov gay
# Processing Record 27 of Set 4 | ouargaye
# Processing Record 28 of Set 4 | pisco
# Processing Record 29 of Set 4 | maragogi
# Processing Record 30 of Set 4 | mayumba
# Processing Record 31 of Set 4 | yumen
# Processing Record 32 of Set 4 | quatre cocos
# Processing Record 33 of Set 4 | paamiut
# Processing Record 34 of Set 4 | hami
# Processing Record 35 of Set 4 | nishihara
# Processing Record 36 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 4 | tasiilaq
# Processing Record 38 of Set 4 | hokitika
# Processing Record 39 of Set 4 | buraydah
# Processing Record 40 of Set 4 | kameshkovo
# Processing Record 41 of Set 4 | rio brilhante
# Processing Record 42 of Set 4 | rio grande
# Processing Record 43 of Set 4 | sri aman
# Processing Record 44 of Set 4 | morant bay
# Processing Record 45 of Set 4 | bocas del toro
# Processing Record 46 of Set 4 | kaitangata
# Processing Record 47 of Set 4 | bethel
# Processing Record 48 of Set 4 | santa cruz de la palma
# Processing Record 49 of Set 4 | khasan
# Processing Record 50 of Set 4 | makakilo city
# Processing Record 1 of Set 5 | allapalli
# Processing Record 2 of Set 5 | jumla
# Processing Record 3 of Set 5 | souillac
# Processing Record 4 of Set 5 | khandagayty
# Processing Record 5 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 5 | ribeira grande
# Processing Record 7 of Set 5 | provideniya
# Processing Record 8 of Set 5 | thompson
# Processing Record 9 of Set 5 | canandaigua
# Processing Record 10 of Set 5 | innisfail
# Processing Record 11 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 5 | lukovetskiy
# Processing Record 13 of Set 5 | gamboma
# Processing Record 14 of Set 5 | panzhihua
# Processing Record 15 of Set 5 | new norfolk
# Processing Record 16 of Set 5 | kysyl-syr
# Processing Record 17 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 5 | aras
# Processing Record 19 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 20 of Set 5 | hamilton
# Processing Record 21 of Set 5 | ciro marina
# Processing Record 22 of Set 5 | rovaniemi
# Processing Record 23 of Set 5 | marsh harbour
# Processing Record 24 of Set 5 | melfi
# Processing Record 25 of Set 5 | riberalta
# Processing Record 26 of Set 5 | skibbereen
# Processing Record 27 of Set 5 | khatanga
# Processing Record 28 of Set 5 | karratha
# Processing Record 29 of Set 5 | barcelona
# Processing Record 30 of Set 5 | matata
# Processing Record 31 of Set 5 | beira
# Processing Record 32 of Set 5 | zile
# Processing Record 33 of Set 5 | bouca
# Processing Record 34 of Set 5 | salinopolis
# Processing Record 35 of Set 5 | maneadero
# Processing Record 36 of Set 5 | bandarbeyla
# Processing Record 37 of Set 5 | pathein
# Processing Record 38 of Set 5 | siwani
# City not found. Skipping...
# Processing Record 39 of Set 5 | vila
# Processing Record 40 of Set 5 | severo-kurilsk
# Processing Record 41 of Set 5 | aquiraz
# Processing Record 42 of Set 5 | margate
# Processing Record 43 of Set 5 | sydney
# Processing Record 44 of Set 5 | wad rawah
# Processing Record 45 of Set 5 | port elizabeth
# Processing Record 46 of Set 5 | khonsa
# Processing Record 47 of Set 5 | soyo
# Processing Record 48 of Set 5 | oum hadjer
# Processing Record 49 of Set 5 | nantucket
# Processing Record 50 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 1 of Set 6 | malakal
# Processing Record 2 of Set 6 | hasaki
# Processing Record 3 of Set 6 | port-gentil
# Processing Record 4 of Set 6 | callaway
# Processing Record 5 of Set 6 | saint-augustin
# Processing Record 6 of Set 6 | chokurdakh
# Processing Record 7 of Set 6 | gobabis
# Processing Record 8 of Set 6 | mercedes
# Processing Record 9 of Set 6 | mount gambier
# Processing Record 10 of Set 6 | gravdal
# Processing Record 11 of Set 6 | inirida
# Processing Record 12 of Set 6 | naze
# Processing Record 13 of Set 6 | gat
# Processing Record 14 of Set 6 | corralillo
# Processing Record 15 of Set 6 | jamestown
# Processing Record 16 of Set 6 | grand gaube
# Processing Record 17 of Set 6 | takoradi
# Processing Record 18 of Set 6 | ancud
# Processing Record 19 of Set 6 | mankono
# Processing Record 20 of Set 6 | berberati
# Processing Record 21 of Set 6 | gualaquiza
# Processing Record 22 of Set 6 | verkhnyaya inta
# Processing Record 23 of Set 6 | vestmanna
# Processing Record 24 of Set 6 | suao
# City not found. Skipping...
# Processing Record 25 of Set 6 | salalah
# Processing Record 26 of Set 6 | atbasar
# Processing Record 27 of Set 6 | port hedland
# Processing Record 28 of Set 6 | afgoye
# City not found. Skipping...
# Processing Record 29 of Set 6 | velen
# Processing Record 30 of Set 6 | gazojak
# Processing Record 31 of Set 6 | batagay
# Processing Record 32 of Set 6 | ekuvukeni
# Processing Record 33 of Set 6 | hualmay
# Processing Record 34 of Set 6 | la ronge
# Processing Record 35 of Set 6 | cabedelo
# Processing Record 36 of Set 6 | floro
# Processing Record 37 of Set 6 | torbay
# Processing Record 38 of Set 6 | lorengau
# Processing Record 39 of Set 6 | lompoc
# Processing Record 40 of Set 6 | codrington
# Processing Record 41 of Set 6 | pulandian
# Processing Record 42 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 43 of Set 6 | tawau
# Processing Record 44 of Set 6 | gaogou
# Processing Record 45 of Set 6 | kharp
# Processing Record 46 of Set 6 | airai
# Processing Record 47 of Set 6 | vardo
# Processing Record 48 of Set 6 | yerbogachen
# Processing Record 49 of Set 6 | kurumkan
# Processing Record 50 of Set 6 | leh
# Processing Record 1 of Set 7 | pedernales
# Processing Record 2 of Set 7 | vresina
# Processing Record 3 of Set 7 | kudahuvadhoo
# Processing Record 4 of Set 7 | laguna
# Processing Record 5 of Set 7 | san patricio
# Processing Record 6 of Set 7 | lagos
# Processing Record 7 of Set 7 | puerto escondido
# Processing Record 8 of Set 7 | khandyga
# Processing Record 9 of Set 7 | faya
# Processing Record 10 of Set 7 | isangel
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | guerrero negro
# Processing Record 13 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 7 | cabra
# Processing Record 15 of Set 7 | kloulklubed
# Processing Record 16 of Set 7 | massafra
# Processing Record 17 of Set 7 | okandja
# City not found. Skipping...
# Processing Record 18 of Set 7 | westport
# Processing Record 19 of Set 7 | caucaia
# Processing Record 20 of Set 7 | mkushi
# Processing Record 21 of Set 7 | luderitz
# Processing Record 22 of Set 7 | ciudad real
# Processing Record 23 of Set 7 | marawi
# Processing Record 24 of Set 7 | barranquilla
# Processing Record 25 of Set 7 | manakara
# Processing Record 26 of Set 7 | geraldton
# Processing Record 27 of Set 7 | trincomalee
# Processing Record 28 of Set 7 | forlev
# Processing Record 29 of Set 7 | nadym
# Processing Record 30 of Set 7 | maceio
# Processing Record 31 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 7 | valparaiso
# Processing Record 33 of Set 7 | dali
# Processing Record 34 of Set 7 | matara
# Processing Record 35 of Set 7 | bonfim
# Processing Record 36 of Set 7 | aykhal
# Processing Record 37 of Set 7 | parati
# Processing Record 38 of Set 7 | ibra
# Processing Record 39 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 7 | port hardy
# Processing Record 41 of Set 7 | at-bashi
# Processing Record 42 of Set 7 | belyy yar
# Processing Record 43 of Set 7 | niquelandia
# Processing Record 44 of Set 7 | faanui
# Processing Record 45 of Set 7 | tsaratanana
# Processing Record 46 of Set 7 | tilichiki
# Processing Record 47 of Set 7 | dubbo
# Processing Record 48 of Set 7 | barabai
# Processing Record 49 of Set 7 | santa marta
# Processing Record 50 of Set 7 | dire
# Processing Record 1 of Set 8 | esperance
# Processing Record 2 of Set 8 | saint-joseph
# Processing Record 3 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 4 of Set 8 | leningradskiy
# Processing Record 5 of Set 8 | mayo
# Processing Record 6 of Set 8 | bilibino
# Processing Record 7 of Set 8 | talgar
# Processing Record 8 of Set 8 | guarda
# Processing Record 9 of Set 8 | saint-leu
# Processing Record 10 of Set 8 | mahajanga
# Processing Record 11 of Set 8 | thayetmyo
# Processing Record 12 of Set 8 | lebu
# Processing Record 13 of Set 8 | ostersund
# Processing Record 14 of Set 8 | ilawe
# Processing Record 15 of Set 8 | lata
# Processing Record 16 of Set 8 | miragoane
# Processing Record 17 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 8 | dingle
# Processing Record 19 of Set 8 | begles
# Processing Record 20 of Set 8 | kununurra
# Processing Record 21 of Set 8 | jackson
# Processing Record 22 of Set 8 | adrar
# Processing Record 23 of Set 8 | sedalia
# Processing Record 24 of Set 8 | bubaque
# Processing Record 25 of Set 8 | seydi
# Processing Record 26 of Set 8 | isilkul
# Processing Record 27 of Set 8 | coihaique
# Processing Record 28 of Set 8 | verkhnevilyuysk
# Processing Record 29 of Set 8 | kruisfontein
# Processing Record 30 of Set 8 | tir pol
# City not found. Skipping...
# Processing Record 31 of Set 8 | namatanai
# Processing Record 32 of Set 8 | zhangjiakou
# Processing Record 33 of Set 8 | kavaratti
# Processing Record 34 of Set 8 | vallenar
# Processing Record 35 of Set 8 | saldanha
# Processing Record 36 of Set 8 | san jeronimo
# Processing Record 37 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 8 | ilebo
# Processing Record 39 of Set 8 | dalby
# Processing Record 40 of Set 8 | chippewa falls
# Processing Record 41 of Set 8 | tabou
# Processing Record 42 of Set 8 | dicabisagan
# Processing Record 43 of Set 8 | linxia
# Processing Record 44 of Set 8 | gvarv
# Processing Record 45 of Set 8 | maslova pristan
# Processing Record 46 of Set 8 | arlit
# Processing Record 47 of Set 8 | sinnamary
# Processing Record 48 of Set 8 | novikovo
# Processing Record 49 of Set 8 | shenjiamen
# Processing Record 50 of Set 8 | vuktyl
# Processing Record 1 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 9 | talnakh
# Processing Record 3 of Set 9 | victor harbor
# Processing Record 4 of Set 9 | obihiro
# Processing Record 5 of Set 9 | houma
# Processing Record 6 of Set 9 | ondjiva
# Processing Record 7 of Set 9 | tapes
# Processing Record 8 of Set 9 | khairagarh
# Processing Record 9 of Set 9 | mahibadhoo
# Processing Record 10 of Set 9 | los llanos de aridane
# Processing Record 11 of Set 9 | cayenne
# Processing Record 12 of Set 9 | alappuzha
# Processing Record 13 of Set 9 | fosses
# Processing Record 14 of Set 9 | nyurba
# Processing Record 15 of Set 9 | behshahr
# Processing Record 16 of Set 9 | camacha
# Processing Record 17 of Set 9 | nemuro
# Processing Record 18 of Set 9 | hare bay
# Processing Record 19 of Set 9 | shimoda
# Processing Record 20 of Set 9 | ellisras
# Processing Record 21 of Set 9 | fukue
# Processing Record 22 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 23 of Set 9 | richmond
# Processing Record 24 of Set 9 | belaya gora
# Processing Record 25 of Set 9 | codajas
# Processing Record 26 of Set 9 | melville
# Processing Record 27 of Set 9 | yulara
# Processing Record 28 of Set 9 | namibe
# Processing Record 29 of Set 9 | nouadhibou
# Processing Record 30 of Set 9 | agogo
# Processing Record 31 of Set 9 | lavrentiya
# Processing Record 32 of Set 9 | longyearbyen
# Processing Record 33 of Set 9 | cap-aux-meules
# Processing Record 34 of Set 9 | plettenberg bay
# Processing Record 35 of Set 9 | palmer
# Processing Record 36 of Set 9 | ixtapa
# Processing Record 37 of Set 9 | neiafu
# Processing Record 38 of Set 9 | myitkyina
# Processing Record 39 of Set 9 | deputatskiy
# Processing Record 40 of Set 9 | darhan
# Processing Record 41 of Set 9 | seymchan
# Processing Record 42 of Set 9 | klaksvik
# Processing Record 43 of Set 9 | dunedin
# Processing Record 44 of Set 9 | mao
# Processing Record 45 of Set 9 | kalulushi
# Processing Record 46 of Set 9 | correntina
# Processing Record 47 of Set 9 | tiznit
# Processing Record 48 of Set 9 | burnie
# Processing Record 49 of Set 9 | mangrul pir
# Processing Record 50 of Set 9 | talcahuano
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | halifax
# Processing Record 3 of Set 10 | volksrust
# Processing Record 4 of Set 10 | kinango
# Processing Record 5 of Set 10 | bolobo
# Processing Record 6 of Set 10 | tambura
# Processing Record 7 of Set 10 | bafq
# Processing Record 8 of Set 10 | sur
# Processing Record 9 of Set 10 | arys
# Processing Record 10 of Set 10 | mbaiki
# Processing Record 11 of Set 10 | kochevo
# Processing Record 12 of Set 10 | axim
# Processing Record 13 of Set 10 | port hawkesbury
# Processing Record 14 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 15 of Set 10 | sioux lookout
# Processing Record 16 of Set 10 | orlik
# Processing Record 17 of Set 10 | vila velha
# Processing Record 18 of Set 10 | ulkan
# Processing Record 19 of Set 10 | flinders
# Processing Record 20 of Set 10 | kutum
# Processing Record 21 of Set 10 | murgab
# Processing Record 22 of Set 10 | pudozh
# Processing Record 23 of Set 10 | nautla
# Processing Record 24 of Set 10 | mehamn
# Processing Record 25 of Set 10 | shellbrook
# Processing Record 26 of Set 10 | ugoofaaru
# Processing Record 27 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 28 of Set 10 | mackay
# Processing Record 29 of Set 10 | oistins
# Processing Record 30 of Set 10 | bara
# Processing Record 31 of Set 10 | meulaboh
# Processing Record 32 of Set 10 | fare
# Processing Record 33 of Set 10 | luanda
# Processing Record 34 of Set 10 | dukat
# Processing Record 35 of Set 10 | roma
# Processing Record 36 of Set 10 | anjozorobe
# Processing Record 37 of Set 10 | umm lajj
# Processing Record 38 of Set 10 | high prairie
# Processing Record 39 of Set 10 | padang
# Processing Record 40 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 41 of Set 10 | saint anthony
# Processing Record 42 of Set 10 | ceska lipa
# Processing Record 43 of Set 10 | estevan
# Processing Record 44 of Set 10 | oranjestad
# Processing Record 45 of Set 10 | nelson bay
# Processing Record 46 of Set 10 | namie
# Processing Record 47 of Set 10 | riyadh
# Processing Record 48 of Set 10 | ukiah
# Processing Record 49 of Set 10 | sungaipenuh
# Processing Record 50 of Set 10 | madang
# Processing Record 1 of Set 11 | marsaxlokk
# Processing Record 2 of Set 11 | strezhevoy
# Processing Record 3 of Set 11 | college
# Processing Record 4 of Set 11 | auki
# Processing Record 5 of Set 11 | preston
# Processing Record 6 of Set 11 | swan hill
# Processing Record 7 of Set 11 | pitimbu
# Processing Record 8 of Set 11 | vostok
# Processing Record 9 of Set 11 | east wenatchee bench
# Processing Record 10 of Set 11 | zhigansk
# Processing Record 11 of Set 11 | mason city
# Processing Record 12 of Set 11 | krasnokamensk
# Processing Record 13 of Set 11 | porto novo
# Processing Record 14 of Set 11 | talakan
# Processing Record 15 of Set 11 | lima
# Processing Record 16 of Set 11 | pemberton
# Processing Record 17 of Set 11 | mount hagen
# Processing Record 18 of Set 11 | araouane
# Processing Record 19 of Set 11 | gambela
# Processing Record 20 of Set 11 | evensk
# Processing Record 21 of Set 11 | ayios matthaios
# City not found. Skipping...
# Processing Record 22 of Set 11 | tocopilla
# Processing Record 23 of Set 11 | itarema
# Processing Record 24 of Set 11 | sakaiminato
# Processing Record 25 of Set 11 | celestun
# Processing Record 26 of Set 11 | road town
# Processing Record 27 of Set 11 | bereda
# Processing Record 28 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 11 | mamlyutka
# Processing Record 30 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 11 | tyrma
# Processing Record 32 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 11 | misratah
# Processing Record 34 of Set 11 | sarkand
# Processing Record 35 of Set 11 | puerto del rosario
# Processing Record 36 of Set 11 | tallahassee
# Processing Record 37 of Set 11 | huilong
# Processing Record 38 of Set 11 | manica
# Processing Record 39 of Set 11 | yavatmal
# Processing Record 40 of Set 11 | cape canaveral
# Processing Record 41 of Set 11 | spiridonovka
# Processing Record 42 of Set 11 | kurilsk
# Processing Record 43 of Set 11 | oranjemund
# Processing Record 44 of Set 11 | cao bang
# Processing Record 45 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 11 | yantal
# Processing Record 48 of Set 11 | viedma
# Processing Record 49 of Set 11 | otukpo
# Processing Record 50 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 12 | alingsas
# Processing Record 2 of Set 12 | mudanjiang
# Processing Record 3 of Set 12 | businga
# Processing Record 4 of Set 12 | sarangani
# Processing Record 5 of Set 12 | jacarezinho
# Processing Record 6 of Set 12 | destin
# Processing Record 7 of Set 12 | la macarena
# Processing Record 8 of Set 12 | lake havasu city
# Processing Record 9 of Set 12 | amapa
# Processing Record 10 of Set 12 | kaminskiy
# Processing Record 11 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 12 of Set 12 | comarapa
# Processing Record 13 of Set 12 | pangnirtung
# Processing Record 14 of Set 12 | port augusta
# Processing Record 15 of Set 12 | dalmatovo
# Processing Record 16 of Set 12 | acajutla
# Processing Record 17 of Set 12 | la ligua
# Processing Record 18 of Set 12 | kaabong
# Processing Record 19 of Set 12 | waipawa
# Processing Record 20 of Set 12 | junagarh
# Processing Record 21 of Set 12 | kayes
# Processing Record 22 of Set 12 | conde
# Processing Record 23 of Set 12 | miri
# Processing Record 24 of Set 12 | lalibela
# Processing Record 25 of Set 12 | prince rupert
# Processing Record 26 of Set 12 | padre bernardo
# Processing Record 27 of Set 12 | rorvik
# Processing Record 28 of Set 12 | udachnyy
# Processing Record 29 of Set 12 | beinamar
# Processing Record 30 of Set 12 | beloha
# Processing Record 31 of Set 12 | balykshi
# Processing Record 32 of Set 12 | aripuana
# Processing Record 33 of Set 12 | biloela
# Processing Record 34 of Set 12 | katangli
# Processing Record 35 of Set 12 | nehe
# Processing Record 36 of Set 12 | vinica
# Processing Record 37 of Set 12 | atambua
# Processing Record 38 of Set 12 | hwange
# Processing Record 39 of Set 12 | sechura
# Processing Record 40 of Set 12 | teya
# Processing Record 41 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 12 | sabang
# Processing Record 43 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 44 of Set 12 | benguela
# Processing Record 45 of Set 12 | ilheus
# Processing Record 46 of Set 12 | passo de camaragibe
# Processing Record 47 of Set 12 | anamur
# Processing Record 48 of Set 12 | oktyabrskiy
# Processing Record 49 of Set 12 | mastic beach
# Processing Record 50 of Set 12 | harlingen
# Processing Record 1 of Set 13 | ucluelet
# Processing Record 2 of Set 13 | sumbe
# Processing Record 3 of Set 13 | sofiysk
# City not found. Skipping...
# Processing Record 4 of Set 13 | plainview
# Processing Record 5 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 13 | hue
# Processing Record 7 of Set 13 | hirara
# Processing Record 8 of Set 13 | trinidad
# Processing Record 9 of Set 13 | campo maior
# Processing Record 10 of Set 13 | channel-port aux basques
# Processing Record 11 of Set 13 | comodoro rivadavia
# Processing Record 12 of Set 13 | iwaki
# Processing Record 13 of Set 13 | nouakchott
# Processing Record 14 of Set 13 | arua
# Processing Record 15 of Set 13 | machali
# Processing Record 16 of Set 13 | pundaguitan
# Processing Record 17 of Set 13 | qaqortoq
# Processing Record 18 of Set 13 | severo-yeniseyskiy
# Processing Record 19 of Set 13 | sisimiut
# Processing Record 20 of Set 13 | sao filipe
# Processing Record 21 of Set 13 | cumberland
# Processing Record 22 of Set 13 | alofi
# Processing Record 23 of Set 13 | brae
# Processing Record 24 of Set 13 | shahrud
# Processing Record 25 of Set 13 | la palma
# Processing Record 26 of Set 13 | mega
# Processing Record 27 of Set 13 | tessalit
# Processing Record 28 of Set 13 | bonavista
# Processing Record 29 of Set 13 | vilyuysk
# Processing Record 30 of Set 13 | balabac
# Processing Record 31 of Set 13 | waw
# Processing Record 32 of Set 13 | dzilam gonzalez
# Processing Record 33 of Set 13 | springbok
# Processing Record 34 of Set 13 | huancabamba
# Processing Record 35 of Set 13 | ruwi
# Processing Record 36 of Set 13 | tutoia
# Processing Record 37 of Set 13 | baruun-urt
# Processing Record 38 of Set 13 | kaeo
# Processing Record 39 of Set 13 | saint-gaudens
# Processing Record 40 of Set 13 | patan
# Processing Record 41 of Set 13 | krasnozatonskiy
# Processing Record 42 of Set 13 | dwarka
# Processing Record 43 of Set 13 | hays
# Processing Record 44 of Set 13 | puerto madryn
# Processing Record 45 of Set 13 | tenenkou
# Processing Record 46 of Set 13 | ahuimanu
# Processing Record 47 of Set 13 | lagoa
# Processing Record 48 of Set 13 | anadyr
# Processing Record 49 of Set 13 | guaira
# Processing Record 50 of Set 13 | luena
# Processing Record 1 of Set 14 | poum
# Processing Record 2 of Set 14 | lovozero
# Processing Record 3 of Set 14 | guilin
# Processing Record 4 of Set 14 | tukrah
# Processing Record 5 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 14 | porto nacional
# Processing Record 7 of Set 14 | alindao
# Processing Record 8 of Set 14 | douentza
# Processing Record 9 of Set 14 | lindsay
# Processing Record 10 of Set 14 | colinas
# Processing Record 11 of Set 14 | the pas
# Processing Record 12 of Set 14 | krasnoselkup
# Processing Record 13 of Set 14 | rampur
# Processing Record 14 of Set 14 | biu
# Processing Record 15 of Set 14 | myrtle beach
# Processing Record 16 of Set 14 | leshukonskoye
# Processing Record 17 of Set 14 | lazaro cardenas
# Processing Record 18 of Set 14 | san ignacio
# Processing Record 19 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 20 of Set 14 | komsomolskiy
# Processing Record 21 of Set 14 | tommot
# Processing Record 22 of Set 14 | hovd
# Processing Record 23 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 24 of Set 14 | dolinsk
# Processing Record 25 of Set 14 | zanjan
# Processing Record 26 of Set 14 | black river
# Processing Record 27 of Set 14 | labuhan
# Processing Record 28 of Set 14 | kupang
# Processing Record 29 of Set 14 | shibarghan
# City not found. Skipping...
# Processing Record 30 of Set 14 | srednekolymsk
# Processing Record 31 of Set 14 | gonzales
# Processing Record 32 of Set 14 | flin flon
# Processing Record 33 of Set 14 | mikhaylovka
# Processing Record 34 of Set 14 | zhezkazgan
# Processing Record 35 of Set 14 | sile
# Processing Record 36 of Set 14 | senneterre
# Processing Record 37 of Set 14 | kralendijk
# Processing Record 38 of Set 14 | tanete
# Processing Record 39 of Set 14 | nampula
# Processing Record 40 of Set 14 | darnah
# Processing Record 41 of Set 14 | san marcos
# Processing Record 42 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 43 of Set 14 | iqaluit
# Processing Record 44 of Set 14 | avera
# Processing Record 45 of Set 14 | seoul
# Processing Record 46 of Set 14 | san quintin
# Processing Record 47 of Set 14 | zabaykalsk
# Processing Record 48 of Set 14 | yinchuan
# Processing Record 49 of Set 14 | juba
# Processing Record 50 of Set 14 | matlock
# Processing Record 1 of Set 15 | middle island
# Processing Record 2 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 15 | stephenville
# Processing Record 4 of Set 15 | acapulco
# Processing Record 5 of Set 15 | djougou
# Processing Record 6 of Set 15 | narsaq
# Processing Record 7 of Set 15 | yarmouth
# Processing Record 8 of Set 15 | havoysund
# Processing Record 9 of Set 15 | port lincoln
# Processing Record 10 of Set 15 | mahaicony
# City not found. Skipping...
# Processing Record 11 of Set 15 | jiaocheng
# Processing Record 12 of Set 15 | gornyy
# Processing Record 13 of Set 15 | san cristobal
# Processing Record 14 of Set 15 | kandrian
# Processing Record 15 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 15 | kursenai
# Processing Record 17 of Set 15 | florianopolis
# Processing Record 18 of Set 15 | taltal
# Processing Record 19 of Set 15 | thiruvananthapuram
# Processing Record 20 of Set 15 | aksarka
# Processing Record 21 of Set 15 | noumea
# Processing Record 22 of Set 15 | bismarck
# Processing Record 23 of Set 15 | suphan buri
# Processing Record 24 of Set 15 | kieta
# Processing Record 25 of Set 15 | tazovskiy
# Processing Record 26 of Set 15 | banda aceh
# Processing Record 27 of Set 15 | bar harbor
# Processing Record 28 of Set 15 | koosa
# Processing Record 29 of Set 15 | tezu
# Processing Record 30 of Set 15 | bani
# Processing Record 31 of Set 15 | inuvik
# Processing Record 32 of Set 15 | mach
# Processing Record 33 of Set 15 | santa cruz del sur
# Processing Record 34 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 35 of Set 15 | changji
# Processing Record 36 of Set 15 | tateyama
# Processing Record 37 of Set 15 | mariestad
# Processing Record 38 of Set 15 | dalbandin
# Processing Record 39 of Set 15 | serpa
# Processing Record 40 of Set 15 | skjervoy
# Processing Record 41 of Set 15 | tirano
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 677

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Albany  42.6001  -73.9662      9.00        51           2        1.01
# 1      Okhotsk  59.3833  143.3000     -8.07        85           0        8.93
# 2     Ilhabela -23.7781  -45.3581     79.48        74         100        2.82
# 3       Atuona  -9.8000 -139.0333     78.58        76           5       18.03
# 4       Avarua -21.2078 -159.7750     78.80        83           2        3.44
# ..         ...      ...       ...       ...       ...         ...         ...
# 672  Mariestad  58.7097   13.8237     15.01        85           0        7.78
# 673  Dalbandin  28.8947   64.4101     65.79        17           1        2.30
# 674      Serpa  37.9458   -7.5975     57.20        94          90       14.97
# 675   Skjervoy  70.0311   20.9714     20.61        89           0       13.80
# 676     Tirano  46.2154   10.1679     39.99        67           2        6.67
#
#     Country Current Description
# 0        US           clear sky
# 1        RU           clear sky
# 2        BR     overcast clouds
# 3        PF           clear sky
# 4        CK           clear sky
# ..      ...                 ...
# 672      SE           clear sky
# 673      PK           clear sky
# 674      PT                 fog
# 675      NO           clear sky
# 676      IT           clear sky
#
# [677 rows x 9 columns]

# %%
new_column_number = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_number]
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Albany      US  42.6001  -73.9662      9.00        51           2
# 1      Okhotsk      RU  59.3833  143.3000     -8.07        85           0
# 2     Ilhabela      BR -23.7781  -45.3581     79.48        74         100
# 3       Atuona      PF  -9.8000 -139.0333     78.58        76           5
# 4       Avarua      CK -21.2078 -159.7750     78.80        83           2
# ..         ...     ...      ...       ...       ...       ...         ...
# 672  Mariestad      SE  58.7097   13.8237     15.01        85           0
# 673  Dalbandin      PK  28.8947   64.4101     65.79        17           1
# 674      Serpa      PT  37.9458   -7.5975     57.20        94          90
# 675   Skjervoy      NO  70.0311   20.9714     20.61        89           0
# 676     Tirano      IT  46.2154   10.1679     39.99        67           2
#
#      Wind Speed Current Description
# 0          1.01           clear sky
# 1          8.93           clear sky
# 2          2.82     overcast clouds
# 3         18.03           clear sky
# 4          3.44           clear sky
# ..          ...                 ...
# 672        7.78           clear sky
# 673        2.30           clear sky
# 674       14.97                 fog
# 675       13.80           clear sky
# 676        6.67           clear sky
#
# [677 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
